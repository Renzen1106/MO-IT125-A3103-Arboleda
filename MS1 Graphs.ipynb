# %%
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv(r'C:\Users\Jonathan School\Desktop\cleaned_social_media_interactions.csv')
dataset.head()
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3020 entries, 0 to 3019
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       3020 non-null   object
#  1   InteractionID    3020 non-null   object
#  2   Platform         3020 non-null   object
#  3   InteractionType  3020 non-null   object
#  4   Sentiment        3020 non-null   object
#  5   InteractionDate  2920 non-null   object
# dtypes: object(6)
# memory usage: 141.7+ KB

# %%
#Sentiment Distribution
#Positive: 905 entries (30.9%)
#Neutral: 874 entries (29.9%)
#Negative: 866 entries (29.6%)
#Very Negative: 34 entries (1.2%)
#Very Positive: 32 entries (1.1%)
#Unknown: 309 entries (10.6%), representing potential data gaps or missing information.

x = ["Postive", "Neutral","Negative", "Very Negative","Very Positive","Unknown"]
y = [905, 874, 866, 34, 32, 309]

plt.bar(x,y)
plt.title("Sentiment Distribution")
plt.show()

# %%
#Engagement Counts
#Instagram: 921 entries (31.5%)
#Twitter: 917 entries (31.4%)
#Facebook: 891 entries (30.5%)
#Unknown platforms: 291 entries (10%), indicating missing or incomplete data that require further investigation.

y = [921, 917, 891, 291]
mylabels = ["Instagram (31.5%)", "Twitter (31.4%)", "Facebook (30.5%)", "Unkown (10%)"]

plt.pie(y, labels = mylabels)
plt.title("Engagement Counts")
plt.show()

# %%
#Interaction types
#Comment: 1,018 (34.9%)
#Share: 1,007 (34.5%)
#Like: 995 (34.1%)

x = ["Comment", "Share", "Like"]
y = [1018, 1007, 995]
plt.bar(x, y)
plt.title("Interaction Types")
plt.show()

# %%
#Payment Methods (Categorical Variable):
#Distribution:
#Debit Card: 767 (25.4%)
#Credit Card: 755 (25%)
#PayPal: 750 (24.9%)
#Bank Transfer: 743 (24.6%)

y = [767, 755, 750, 743]
mylabels2 = ["Debit Card (25.4%)", "Credit Card (25%)", "PayPal (24.9%)", "Bank Transfer (24.6%)"]
plt.pie(y, labels = mylabels2)
plt.title("Payment Methods (Categorical Variable)")
plt.show()

# %%
#Product Categories (Categorical Variable):
#Counts:
#Clothing: 853 (28.3%)
#Electronics: 564 (18.7%)
#Automotive: 540 (17.9%)
#Home & Garden: 530 (17.6%)
#Health & Beauty: 528 (17.5%)

y = [853, 564, 540, 530, 528]
x = ["Clothing", "Electronics", "Automotive", "Home & Garden", "Health & Beauty"]
plt.bar(x, y)
plt.title("Product Categories (Categorical Variable)")
plt.show()
